# %%
import numpy as np

# %% [markdown]
# Daily Student Productivity Data
# ## Daily time (in hours): [study, entertainment, sleep]
# time_data = [
# (3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (2.5, 3.0, 8.0),
# (4.0, 2.0, 6.0), (1.5, 4.5, 9.0), (3.0, 2.5, 7.5),
# (5.5, 1.0, 6.0), (2.0, 3.5, 8.5), (4.5, 2.0, 7.0),
# (3.0, 3.0, 7.5), (6.0, 1.5, 6.0), (2.5, 4.0, 8.0),
# (4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)
# ]

# %% [markdown]
# Task 1. Classify Study Time:
# 1. Create empty lists for study time classifications:
# (a) Low: less than 3 hours.
# (b) Moderate: between 3 and 5 hours.
# (c) High: more than 5 hours.

# %%
time_data = [ (3.5, 2.0, 7.0),
 (5.0, 1.5, 6.5), (2.5, 3.0, 8.0), (4.0, 2.0, 6.0),
  (1.5, 4.5, 9.0), (3.0, 2.5, 7.5), (5.5, 1.0, 6.0),
  (2.0, 3.5, 8.5), (4.5, 2.0, 7.0), (3.0, 3.0, 7.5),
  (6.0, 1.5, 6.0), (2.5, 4.0, 8.0), (4.0, 2.5, 7.0),
  (5.0, 2.0, 6.5), (3.5, 2.5, 7.0) ]
Low_Time = []
Moderate_Time = []
High_Time = []

# %% [markdown]
# 2. Iterate over the time_data list and add each study hour to the appropriate category.

# %%
for studytime in time_data:
  if studytime[0] < 3:
    Low_Time.append(studytime)
  elif studytime[0] >= 3 and studytime[0] <=5:
    Moderate_Time.append(studytime)
  else:
    High_Time.append(studytime)

# %% [markdown]
# 3. Print the lists to verify the classifications.

# %%
print(f" Low study time: {Low_Time}")
print(f"Moderate study time: {Moderate_Time}")
print(f"High study time: {High_Time}")
# Out:
#  Low study time: [(2.5, 3.0, 8.0), (1.5, 4.5, 9.0), (2.0, 3.5, 8.5), (2.5, 4.0, 8.0)]
# Moderate study time: [(3.5, 2.0, 7.0), (5.0, 1.5, 6.5), (4.0, 2.0, 6.0), (3.0, 2.5, 7.5), (4.5, 2.0, 7.0), (3.0, 3.0, 7.5), (4.0, 2.5, 7.0), (5.0, 2.0, 6.5), (3.5, 2.5, 7.0)]
# High study time: [(5.5, 1.0, 6.0), (6.0, 1.5, 6.0)]

# %% [markdown]
# Task 2. Based on Data – Answer all the Questions:
# 1. How many days had low study time?

# %%
number_of_low_study = len(Low_Time)
print(f"number of low study time: {number_of_low_study }")
# Out:
# number of low study time: 4

# %% [markdown]
# 2. How many days had moderate study time?

# %%
number_of_moderate_study = len(Moderate_Time)
print(f"number of moderate study time: {number_of_moderate_study }")
# Out:
# number of moderate study time: 9

# %% [markdown]
# 3. How many days had high study time?

# %%
number_of_high_study = len(High_Time)
print(f"number of high study time: {number_of_high_study }")
# Out:
# number of high study time: 2

# %% [markdown]
# Task 3. Convert Study Hours to Minutes:
# Convert each study hour value into minutes and store it in a new list called study_minutes.
#
# Formula: Minutes = Hours × 60
#
# 1. Iterate over the time_data list and apply the formula to the study hours.
# 2. Store the results in the new list.
# 3. Print the converted values.

# %%
study_minutes = []
for studytime in time_data:
  study_minutes.append(studytime[0] * 60)
print(f"Total Study Minutes : {study_minutes}")
# Out:
# Total Study Minutes : [210.0, 300.0, 150.0, 240.0, 90.0, 180.0, 330.0, 120.0, 270.0, 180.0, 360.0, 150.0, 240.0, 300.0, 210.0]

# %% [markdown]
# Task 4. Analyze Average Time Use:
# Scenario: Each record contains daily hours of study, entertainment, and sleep.
# 1. Create empty lists for study_hours, entertainment_hours, and sleep_hours.

# %%
study_hours = []
entertainment_hours = []
sleep_hours = []

# %% [markdown]
# 2. Iterate over time_data and extract values into each list.

# %%
for studytime in time_data:
  study_hours.append(studytime[0])
  entertainment_hours.append(studytime[1])
  sleep_hours.append(studytime[2])

# %% [markdown]
# 3. Calculate and print:
# (a) Average hours spent studying.
# (b) Average hours spent on entertainment.
# (c) Average hours spent sleeping.

# %%
total_study_hours = 0
total_entertainment_hours = 0
total_sleep_hours = 0

for hours in study_hours:
  total_study_hours += hours
for data in entertainment_hours:
  total_entertainment_hours += hours
for data in sleep_hours:
  total_sleep_hours += hours

#a) Average hours spent studying
avg_study_hours = total_study_hours / len(study_hours)
print(f"Average hours spent studying:  {avg_study_hours}")

#b) Average hours spent on entertainment.
avg_entertainment_hours = total_entertainment_hours / len(entertainment_hours)
print(f" Average hours spent on entertainment: {avg_entertainment_hours}")

#c) Average hours spent sleeping.
avg_sleep_hours = total_sleep_hours / len(sleep_hours)
print(f"Average hours spent sleeping: {avg_sleep_hours}")
# Out:
# Average hours spent studying:  3.7
#  Average hours spent on entertainment: 3.5
# Average hours spent sleeping: 3.5

# %% [markdown]
# Task 5. Visualization - Study vs Sleep Pattern:
# 1. Import matplotlib.pyplot as plt.

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# 2. Plot a scatter plot with:
# • x-axis: Study hours
# • y-axis: Sleep hours
#
# 3. Add labels, title, and color.

# %%
plt.scatter(study_hours, sleep_hours, color = "blue")
plt.grid(True)
plt.xlabel("Study Hours")
plt.ylabel("Sleep Hours")
plt.title("Study Hours vs Sleep Hours")
# Out:
# Text(0.5, 1.0, 'Study Hours vs Sleep Hours')

# %% [markdown]
# 8.1.1 Exercise - Recursion:
#
# Task 1 - Sum of Nested Lists:
# Scenario: You have a list that contains numbers and other lists of numbers (nested lists).
# You want to find the total sum of all the numbers in this structure.
# Task:
#
# • Write a recursive function sum_nested_list(nested_list) that:
# 1. Takes a nested list (a list that can contain numbers or other lists of numbers) as
# input.
# 2. Sums all numbers at every depth level of the list, regardless of how deeply nested
# the numbers are.
#
# • Test the function with a sample nested list, such as
# nested_list = [1, [2, [3, 4], 5], 6, [7, 8]].
# The result should be the total sum of all the numbers.

# %%
def sum_nested_list(nested_list):
    total = 0
    for num in nested_list:
        if isinstance(num, list):
            total += sum_nested_list(num)
        else:
            total += num
    return total

nested_list = [1, [2, [3, 4], 5], 6, [7, 8]]
total_sum = sum_nested_list(nested_list)
print(f"The sum of numbers in the list: {total_sum}")
# Out:
# The sum of numbers in the list is : 36

# %% [markdown]
# Task 2 - Generate All Permutations of a String:
# Scenario: Given a string, generate all possible permutations of its characters. This is useful
# for understanding backtracking and recursive depth-first search.
# Task:
# • Write a recursive function generate_permutations(s) that:
# – Takes a string s as input and returns a list of all unique permutations.
# • Test with strings like ”abc” and ”aab”.
#
# print(generate_permutations("abc"))
# ### Should return [’abc’, ’acb’, ’bac’, ’bca’, ’cab’, ’cba’]

# %%
def generate_permutations(s):
  if len(s) == 1:
    return[s]
  total_char = []
  for character in s:
    if character in total_char:
      continue
    else:
      total_char.append(character)
  new_char = ""
  for character in total_char:
    new_char += character
  result = []
  for i, charac in enumerate(new_char):
    result += [charac + j for j in generate_permutations(new_char[:i] + new_char[i+1:])]
  return result

charac = "aaabc"
print(generate_permutations(charac))
# Out:
# ['abc', 'acb', 'bac', 'bca', 'cab', 'cba']

# %% [markdown]
# Task 3
# # Sample directory structure
# directory_structure = {
# "file1.txt": 200,
# "file2.txt": 300,
# "subdir1": {
# "file3.txt": 400,
# "file4.txt": 100
# },
# "subdir2": {
# "subsubdir1": {
# "file5.txt": 250
# },
# "file6.txt": 150
# }
# }
# 1. Write a recursive function calculate_directory_size(directory) where:
# • directory is a dictionary where keys represent file names (with values as sizes in KB) or directory names (with values as another dictionary representing a subdi-
# rectory).
#
# • The function should return the total size of the directory, including all nested
# subdirectories.

# %%
def calculate_directory_size(directory):
    total_size = 0
    for k,v in directory.items():
        if isinstance(v, dict):
            total_size += calculate_directory_size(v)
        else:
            total_size += v
    return total_size

directory_structure = {
"file1.txt": 200, "file2.txt": 300,
"subdir1": { "file3.txt": 400, "file4.txt": 100 },
"subdir2": { "subsubdir1": { "file5.txt": 250 },
"file6.txt": 150 }
}

total_directory_size = calculate_directory_size(directory_structure)
print(f"Total directory size : {total_directory_size} KB")
# Out:
# Total directory size : 1400 KB

# %% [markdown]
# 8.2.1 Exercises - Dynamic Programming:
#
# Task 1 - Coin Change Problem:
# Scenario: Given a set of coin denominations and a target amount, find the minimum number
# of coins needed to make the amount. If it’s not possible, return - 1.
# Task:
# 1. Write a function min_coins(coins, amount) that:
# • Uses DP to calculate the minimum number of coins needed to make up the
# amount.

# %%
def min_coins(coins, amount):
  dp = [amount + 1] * (amount + 1)
  dp[0] = 0

  for var in coins:
    for i in range(var, amount + 1):
      dp[i] = min(dp[i], dp[i - var] + 1)
  if dp[amount] != (amount + 1):
    return dp[amount]
# Out:
# 3

# %% [markdown]
# #####2. Test with coins = [1, 2, 5] and amount = 11. The result should be 3 (using coins [5, 5, 1]).

# %%
coins = [1, 2, 5]
total_amount = 11
print(min_coins(coins, total_amount))
# Out:
# 3

# %% [markdown]
# Task 2 - Longest Common Subsequence (LCS):
# Scenario: Given two strings, find the length of their longest common subsequence (LCS).
# This is useful in text comparison.
# Task:
# 1. Write a function longest_common_subsequence(s1, s2) that:
# • Uses DP to find the length of the LCS of two strings s1 and s2.

# %%
def longest_common_subsequence(string1, string2):
  l1= len(string1)
  l2 = len(string2)
  dp = [[0] * (l2 + 1) for length in range(l1 + 1)]

  for i in range(1, l1 + 1):
    for j in range(1, l2 + 1):
      if string1[i - 1] == string2[j - 1]:
        dp[i][j] = dp[i - 1][j - 1] + 1
      else:
        dp[i][j] = max(dp[i - 1][j], dp[i][j - 1])
  return dp[l1][l2]

# %% [markdown]
# 2. Test with strings like "abcde" and "ace"; the LCS length should be 3 ("ace").

# %%
print(longest_common_subsequence("ace", "abcde"))
# Out:
# 3

# %% [markdown]
# Task 3 - 0/1 Knapsack Problem:
# Scenario: You have a list of items, each with a weight and a value. Given a weight capacity,
# maximize the total value of items you can carry without exceeding the weight capacity.
# Task:
# 1. Write a function knapsack(weights, values, capacity) that:
# • Uses DP to determine the maximum value that can be achieved within the given
# weight capacity.

# %%
def knapsack(capacity, weight, value):
  l = len(value)
  dp = {}
  for i in range(capacity + 1):
    dp[(0,i)] = 0

  for i in range(1, l + 1):
    for j in range(capacity + 1):
      if weight[i - 1] <= j:
        dp[(i, j)] = max(dp[(i - 1, j)], value[i - 1] + dp[(i - 1), j - weight[i -1]])
      else:
        dp[(i, j)] = dp[(i - 1, j)]
  return dp[(l, capacity)]

# %% [markdown]
# 2. Test with weights [1, 3, 4, 5], values [1, 4, 5, 7], and capacity 7. The re-
# sult should be 9.

# %%
weight = [1, 3, 4, 5]
value = [1, 4, 5, 7]
capacity = 7

print(knapsack(capacity, weight, value))
# Out:
# 9
